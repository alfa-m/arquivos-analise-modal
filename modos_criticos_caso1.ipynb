# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
modos_criticos_df = pd.read_csv("./modos_criticos_y_caso1.csv", index_col=0)

# %%
modos_criticos_df.sort_values(by="frequência", inplace=True)
modos_criticos_df
# Out:
#       frequência  local     magnitude
# 5001        60.0  888.3   3042.689415
# 5002        60.5  888.3   3067.048866
# 5023        61.0  888.3   3091.482122
# 5024        61.5  888.2   3115.988154
# 5045        62.0  888.3   3140.565942
# ...          ...    ...           ...
# 4396      2998.0  846.2  58813.481497
# 4397      2998.5  846.3  58824.259916
# 4398      2999.0  846.3  58835.038251
# 4399      2999.5  846.3  58845.816502
# 4402      3000.0  846.3  58856.594669
#
# [5881 rows x 3 columns]

# %%
modos_criticos_df2 = modos_criticos_df.groupby("local").count()
modos_criticos_df2.sort_values(by="frequência", ascending=False, inplace=True)
modos_criticos_df2.describe()
# Out:
#        frequência   magnitude
# count   22.000000   22.000000
# mean   267.318182  267.318182
# std    233.369804  233.369804
# min      5.000000    5.000000
# 25%     98.250000   98.250000
# 50%    166.500000  166.500000
# 75%    360.250000  360.250000
# max    943.000000  943.000000

# %%
modos_criticos_df2
# Out:
#         frequência  magnitude
# local
# 890.3          943        943
# 890.1          660        660
# 890.2          628        628
# 852r.1         450        450
# 848.2          371        371
# 838.2          361        361
# 864.1          358        358
# 848.3          346        346
# 852r.3         244        244
# 852r.2         214        214
# 848.1          170        170
# 888.2          163        163
# 888.1          157        157
# 888.3          155        155
# 856.2          147        147
# 852.1          135        135
# 846.1           86         86
# 852.3           85         85
# 846.3           85         85
# 852.2           65         65
# 846.2           53         53
# 844.3            5          5

# %%
fig, ax = plt.subplots()
bar_container = ax.barh(modos_criticos_df2.index, modos_criticos_df2["frequência"], height=0.6)
ax.set(title="Incidência de modos críticos por barra",xlim=(0, 1010))
ax.bar_label(bar_container, padding=2)
plt.show()
